# %% [markdown]
# # Function Based Approaches

# %%
import sys
import os
import warnings

warnings.filterwarnings('ignore')
sys.path.insert(0, os.path.abspath(os.path.join(os.path.dirname('src'), '..')))

from src.constants import *
from src.data import *
from src.missingness import *
from src.imputation import *
from src.tda import *
from src.visualize import *
from src.normalize import *
from src.metrics import *
from src.utils import *

# %% [markdown]
# ## IRIS Dataset

# %%
IRIS = get_data(IRIS_DATASET_ID)
print(IRIS.data)
print(IRIS.target)
# Out:
#      sepallength  sepalwidth  petallength  petalwidth
# 0            5.1         3.5          1.4         0.2
# 1            4.9         3.0          1.4         0.2
# 2            4.7         3.2          1.3         0.2
# 3            4.6         3.1          1.5         0.2
# 4            5.0         3.6          1.4         0.2
# ..           ...         ...          ...         ...
# 145          6.7         3.0          5.2         2.3
# 146          6.3         2.5          5.0         1.9
# 147          6.5         3.0          5.2         2.0
# 148          6.2         3.4          5.4         2.3
# 149          5.9         3.0          5.1         1.8
#
# [150 rows x 4 columns]
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# ...

# %% [markdown]
# ## Vietoris-Rips Complex

# %%
vr = vietoris_rips_complex(IRIS.data)
plot_persistence_diagram(vr)

# %%
plot_persistence_landscape(persistence_landscape(vr))

# %%
plot_persistence_image(persistence_image(vr))

# %% [markdown]
# ## Distance To a Measure

# %%
dtm = distance_to_a_measure(IRIS.data)
plot_persistence_diagram(dtm)

# %%
plot_persistence_landscape(persistence_landscape(dtm))

# %%
plot_persistence_image(persistence_image(dtm))

# %% [markdown]
# ## Kernel Denstity Estimations

# %%
kd = kernel_distance(IRIS.data)
plot_persistence_diagram(kd)

# %%
plot_persistence_landscape(persistence_landscape(kd))

# %%
plot_persistence_image(persistence_image(kd))
