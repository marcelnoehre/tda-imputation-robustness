# %% [markdown]
# # Function Based Approaches

# %%
import sys
import os
import warnings

warnings.filterwarnings('ignore')
sys.path.insert(0, os.path.abspath(os.path.join(os.path.dirname('src'), '..')))

from sklearn.pipeline import Pipeline

from src.constants import *
from src.data import *
from src.missingness import *
from src.imputation import *
from src.tda import *
from src.visualize import *
from src.normalize import *
from src.metrics import *
from src.utils import *

# %% [markdown]
# ## IRIS Dataset

# %%
IRIS = get_data(IRIS_DATASET_ID)
print(IRIS.data)
print(IRIS.target)
# Out:
#      sepallength  sepalwidth  petallength  petalwidth
# 0            5.1         3.5          1.4         0.2
# 1            4.9         3.0          1.4         0.2
# 2            4.7         3.2          1.3         0.2
# 3            4.6         3.1          1.5         0.2
# 4            5.0         3.6          1.4         0.2
# ..           ...         ...          ...         ...
# 145          6.7         3.0          5.2         2.3
# 146          6.3         2.5          5.0         1.9
# 147          6.5         3.0          5.2         2.0
# 148          6.2         3.4          5.4         2.3
# 149          5.9         3.0          5.1         1.8
#
# [150 rows x 4 columns]
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# ...

# %% [markdown]
# ## Vietoris-Rips Complex

# %%
vr = vietoris_rips_complex()
vr_diagrams = vr.fit_transform(as_batch(IRIS.data))
plot_persistence_diagram(vr_diagrams)

# %%
vr_landscape = PersistenceLandscape().fit_transform(vr_diagrams)
plot_persistence_landscape(vr_landscape[0])

# %% [markdown]
# ## Distance To a Measure

# %%
dtm = distance_to_a_measure()
dtm_diagrams = dtm.fit_transform(as_batch(IRIS.data))
plot_persistence_diagram(dtm_diagrams)

# %%
dtm_landscape = PersistenceLandscape().fit_transform(dtm_diagrams)
plot_persistence_landscape(dtm_landscape[0])

# %% [markdown]
# ## Kernel Denstity Estimations

# %%
kde = kernel_density_estimation(IRIS.data)
kde_diagrams = kde.fit_transform(as_batch(IRIS.data))
plot_persistence_diagram(kde_diagrams)

# %%
kde_landscape = persistence_landscape.fit_transform(kde_diagrams)
plot_persistence_landscape(kde_landscape[0])

# %%
kde_landscape = PersistenceLandscape().fit_transform(kde_diagrams)
plot_persistence_landscape(kde_landscape[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 plot_persistence_diagram(normalize_persistence_diagram(kde))
#
# NameError: name 'normalize_persistence_diagram' is not defined

# %%
dtm = distance_to_a_measure(IRIS.data)
diagrams = dtm.fit_transform(as_batch(IRIS.data))
plot_persistence_diagram(diagrams, 'IRIS - Distance to a Measure')

# %%
kde = kernel_density_estimation(IRIS.data)
diagrams = kde.fit_transform(as_batch(IRIS.data))
plot_persistence_diagram(diagrams, 'IRIS - Kernel Density Estimation')
