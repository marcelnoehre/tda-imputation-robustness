# %%
import sys
import os
import tadasets
import matplotlib.pyplot as plt

sys.path.insert(0, os.path.abspath(os.path.join(os.path.dirname('src'), '..')))

from src.constants import SEED

torus = tadasets.torus(n=2000, c=2, a=1, ambient=200, seed=SEED)
swiss_roll = tadasets.swiss_roll(n=2000, r=4, ambient=10, seed=SEED)
infty_sign = tadasets.infty_sign(n=3000, seed=SEED)
eyeglasses = tadasets.eyeglasses(n=1000, r1=1, r2=2, neck_size=.5, ambient=10, seed=SEED)

# %%
tadasets.plot3d(torus)
# Out:
# <Axes3D: >

# %%
tadasets.plot3d(swiss_roll)
# Out:
# <Axes3D: >

# %%
plt.scatter(infty_sign[:, 0], infty_sign[:, 1])
plt.show()

# %%
plt.scatter(eyeglasses[:, 0], eyeglasses[:, 1])
plt.show()
